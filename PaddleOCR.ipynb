# %%
# !pip install paddleocr
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 445.9/445.9 kB 3.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 813.9/813.9 kB 8.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 299.2/299.2 kB 8.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 19.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 27.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.9/60.9 MB 14.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.1/67.1 MB 8.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 62.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 73.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.3/88.3 kB 8.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 148.4/148.4 kB 13.5 MB/s eta 0:00:00
# ...

# %%
# !apt-get update
# !apt-get install -y libssl-dev
# Out:
# Get:1 http://security.ubuntu.com/ubuntu jammy-security InRelease [110 kB]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [119 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [108 kB]
# Hit:7 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Get:9 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [1,087 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,230 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy-backports/universe amd64 Packages [25.6 kB]
# Hit:12 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# ...

# %%
# !pip install paddlepaddle==2.5.1 -i https://pypi.tuna.tsinghua.edu.cn/simple
# python -m pip install paddlepaddle==2.5.1 -i https://pypi.tuna.tsinghua.edu.cn/simple
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.9/124.9 MB 5.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.4/75.4 kB 8.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 383.2/383.2 kB 23.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.5/74.5 kB 6.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 5.9 MB/s eta 0:00:00
# ...

# %%
import subprocess

# Download libssl1.1 package using wget
wget_command = "wget http://nz2.archive.ubuntu.com/ubuntu/pool/main/o/openssl/libssl1.1_1.1.1f-1ubuntu2.19_amd64.deb"
subprocess.run(wget_command, shell=True, check=True)

# Install libssl1.1 package using dpkg
dpkg_command = "sudo dpkg -i libssl1.1_1.1.1f-1ubuntu2.19_amd64.deb"
subprocess.run(dpkg_command, shell=True, check=True)
# Out:
# CompletedProcess(args='sudo dpkg -i libssl1.1_1.1.1f-1ubuntu2.19_amd64.deb', returncode=0)

# %%
from paddleocr import PaddleOCR, draw_ocr

# %%
ocr = PaddleOCR(use_angle_cls=True, lang='korean') # need to run only once to download and load model into memory
# img_path = '/content/drive/MyDrive/Colab Notebooks/OCR/namecard.jpg'
img_path = '/content/drive/MyDrive/Colab Notebooks/OCR/KakaoTalk_20230731_162813475.jpg'
result = ocr.ocr(img_path, cls=True)
# for line in result:
#     print(line)
print(result[0])
# Out:
# [2023/07/31 07:30:28] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='/root/.paddleocr/whl/det/ml/Multilingual_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='/root/.paddleocr/whl/rec/korean/korean_PP-OCRv3_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25, rec_char_d
# ...

# %%
print(result[0][2][-1][0].split('-'))
# Out:
# ['971015', '1068']

# %%
img_path = '/content/drive/MyDrive/Colab Notebooks/OCR/images.jfif'
result = ocr.ocr(img_path, cls=True)
# Out:
# [2023/07/31 07:34:33] ppocr DEBUG: dt_boxes num : 11, elapse : 0.10442399978637695
# [2023/07/31 07:34:33] ppocr DEBUG: cls num  : 11, elapse : 0.16426491737365723
# [2023/07/31 07:34:35] ppocr DEBUG: rec_res num  : 11, elapse : 1.6552245616912842

# %%
for line in result[0]:
  print(line, end='\n')
# Out:
# [[[33.0, 6.0], [143.0, 6.0], [143.0, 27.0], [33.0, 27.0]], ('주민등록증', 0.9179525375366211)]
# [[[67.0, 28.0], [112.0, 28.0], [112.0, 40.0], [67.0, 40.0]], ('[필리국민', 0.5914369225502014)]
# [[[19.0, 52.0], [100.0, 52.0], [100.0, 78.0], [19.0, 78.0]], ('홍길동', 0.9910011291503906)]
# [[[21.0, 81.0], [67.0, 84.0], [66.0, 99.0], [21.0, 97.0]], ('12345', 0.8230658769607544)]
# [[[66.0, 83.0], [120.0, 80.0], [120.0, 97.0], [67.0, 99.0]], ('78dd1?', 0.615999162197113)]
# [[[119.0, 104.0], [155.0, 104.0], [155.0, 120.0], [119.0, 120.0]], ('00톤', 0.5578469634056091)]
# [[[108.0, 141.0], [161.0, 139.0], [162.0, 155.0], [109.0, 157.0]], ('22', 0.9145819544792175)]
# [[[110.0, 158.0], [171.0, 158.0], [171.0, 173.0], [110.0, 173.0]], ('저물특별시', 0.8426834940910339)]
# [[[171.0, 158.0], [238.0, 155.0], [239.0, 171.0], [171.0, 174.0]], ('00구첨적', 0.6366931200027466)]
